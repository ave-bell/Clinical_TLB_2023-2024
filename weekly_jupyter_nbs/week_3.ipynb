# %% [markdown]
# Week 3 Progress: Getting LC TLB into a Python Environment.

# %%
# step 0: run these commands in the terminal
    # py -m pip install pandas
    # py -m pip install openpyxl

# import modules
import pandas as pd # alias as pd

# %%
# import excel file as a pandas df
df = pd.read_excel("/Users/avery/OneDrive/Desktop/Fall_2023/STA485/tbl_lc/weekly_jupyter_nbs/lung_cancer_publication.xlsx")

# view first 10 rows of df, use df.tail(10) to see last 10 rows
df.head(10)
# Out:
#   sample_id pub_id       T45     T45.1     T45.2     T45.3     T45.4  \
# 0    C68401    L18  0.002960  0.003160  0.003460  0.003700  0.003520
# 1    C69101    L22  0.000600  0.000330  0.000301  0.000271  0.000206
# 2    C68901    L21  0.001320  0.001210  0.001230  0.001320  0.001300
# 3    C67801    L14  0.000786  0.001020  0.001020  0.001310  0.001220
# 4    C68801    L20  0.000492  0.000240 -0.000236 -0.000353 -0.000171
# 5    C68201    L17 -0.000989 -0.000970 -0.001250 -0.001190 -0.001250
# 6    C61701     L9  0.001340  0.001580  0.001600  0.001840  0.001930
# 7    C67901    L15 -0.000518 -0.000813 -0.001180 -0.001490 -0.001610
# 8    C55701     L4  0.004260  0.004490  0.004620  0.004580  0.004860
# 9    C67201    L13  0.001260  0.001190  0.001070  0.001210  0.001640
#
#       T45.5     T45.6     T45.7  ...             Surgery Details  \
# 0  0.003350  0.003040  0.002850  ...                         NaN
# 1  0.000184  0.000318  0.000592  ...                         NaN
# 2  0.001450  0.001510  0.001710  ...                         NaN
# 3  0.001020  0.001060  0.001320  ...                         NaN
# 4  0.000167  0.000584  0.000863  ...                         NaN
# 5 -0.001360 -0.001570 -0.001680  ...                         NaN
# 6  0.002090  0.002040  0.002260  ...                         NaN
# 7 -0.001670 -0.001390 -0.001170  ...                         NaN
# 8  0.005080  0.004680  0.004340  ...  Right VATS wedge resection
# 9  0.001710  0.001510  0.001150  ...                         NaN
#
#    surgery date (days prior to collection)    Outcome...59    Data Type  \
# 0                                      NaN             NaN          NaN
# 1                                      NaN             NaN          NaN
# 2                                      NaN             NaN  Progression
# 3                                      NaN             NaN          NaN
# 4                                      NaN             NaN          NaN
# 5                                      NaN             NaN          NaN
# 6                                      NaN             NaN          NaN
# 7                                      NaN             NaN          NaN
# 8                                      0.0  adenocarcinoma          NaN
# 9                                      NaN             NaN          NaN
#
#    R/P days prior to visit  Recurrence/Progression Location  \
# 0                      NaN                              NaN
# 1                      NaN                              NaN
# 2                     28.0             [Lung],[Lymph Nodes]
# 3                      NaN                              NaN
# 4                      NaN                              NaN
# 5                      NaN                              NaN
# 6                      NaN                              NaN
# 7                      NaN                              NaN
# 8                      NaN                              NaN
# 9                      NaN                              NaN
#
#    Progression free survival  overall survival  Alive.dead.  \
# 0                      775.0            1390.0            1
# 1                        NaN             351.0            1
# 2                      419.0            1239.0            1
# 3                     1216.0            1216.0            0
# 4                      111.0             164.0            1
# 5                        NaN              38.0            1
# 6                        NaN               NaN         UNKN
# 7                      268.0             621.0            1
# 8                     1403.0            1403.0            0
# 9                        NaN             882.0            1
#
#              personal history of cancer
# 0                                   NaN
# 1  CANNABIS DEPENDENCE, UNSPECIFIED USE
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
#
# [10 rows x 538 columns]

# %%
# view the datatypes
df.dtypes
# Out:
# sample_id                           object
# pub_id                              object
# T45                                float64
# T45.1                              float64
# T45.2                              float64
#                                     ...
# Recurrence/Progression Location     object
# Progression free survival          float64
# overall survival                   float64
# Alive.dead.                         object
# personal history of cancer          object
# Length: 538, dtype: object
